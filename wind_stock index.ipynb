,AS51.GI,NZ50.GI,JKSE.GI,KLSE.GI,SETI.GI,PSI.GI,BLOM.GI,VNINDEX.GI,SASEIDX.GI,000001.SH,399001.SZ,HSI.HI,TWII.TW,USDCNH.FX,EURUSD.FX,USDJPY.FX,GBPUSD.FX,USDCAD.FX,AUDUSD.FX,NZDUSD.FX,USDCHF.FX,USDHKD.FX,USDTWD.FX,CNYX.CNI,USDCNY.EX,EURCNY.EX,GBPCNY.EX,JPYCNY.EX,HKDCNY.EX,AUDCNY.EX,CADCNY.EX,CNYRUB.EX,CNYMYR.EX,NZDCNY.EX,SGDCNY.EX,CHFCNY.EX,CNYZAR.EX,CNYKRW.EX", "open,close,high,low","tradeDate=20210315;priceAdj=U;cycle=D")

# %%
import csv
import os
os.path
# Out:
# <module 'ntpath' from 'e:\\anaconda\\envs\\py36\\lib\\ntpath.py'>

# %%
current_dir = 'c:\\winpython\\short324_d' # set storage path 定义存储路径

# %%
# In order to easily obtain the codes of the corresponding financial data items, you can use the code generator that comes with wind to get the names of all items.// 为了便捷的获得对应金融数据条目的代码，可以利用wind自带的代码生成器来获得所有条目的名字
namelist0="ADX.GI,AMX.GI,AS52.GI,ATXPRIME.GI,BELSTK.GI,BSE500.GI,BTK.GI,BURCAP.GI,BUX.GI,BVLX.GI,CASE.GI,CCSI.GI,CDAX.F,CHTX.GI,CN20.GI,DFM.GI,DJCH30.GI,DJCOMP.GI,DJDWCF.GI,DJES30.GI,DJTR20I.GI,FBMEMAS.FI,FSTAS.FI,FSTRE.GI,FT350.FI,FTASE.FI,FTDUAE.FI,FTITMC.FI,FTSEM.FI,FTSEMIB.FI,HDAX.F,HERMES.GI,HEX25.FIN,HEXP.FIN,IBOVESPA.GI,IBOVIEE.GI,IBX.GI,IGPA.GI,IMC30.GI,IMOEX.MCX,INMEX.GI,INTER10.GI,IPSA.GI,ITLMS.GI,JKLQ45.JK,KOSPI200.GI,KRX100.GI,LUXXR.GI,MAR.GI,MCX10.MCX,NBI.GI,NGSEINDX.GI,NIFTY.GI,NZSE.GI,NZSE10.GI,OBX.GI,OBXP.GI,OMXC25.GI,PFTS.GI,PSI20.GI,RUI.GI,RXS.GI,S50.THA,SBF250.GI,SPI.GI,SPTSX60.GI,SWIG80.GI,SX5E.GI,SX5P.GI,SXXE.GI,SXXP.GI,TA-35.GI,TXEQ.GI,UX.GI,VHINDEX.GI,WBI.GI,WIG.GI,WIG20.GI,XU030.GI,XU100.GI,DJI.GI,IXIC.GI,SPX.GI,NDX.GI,RTY.GI,XMI.GI,NYA.GI,XAX.GI,CHXN.GI,GSPTSE.GI,MERV.GI,MXX.GI,IBVC.GI,FTSE.GI,GDAXI.GI,FCHI.GI,SMSI.GI,IBEX.GI,AEX.GI,RTS.GI,OMXSPI.GI,SSMI.GI,BFX.GI,ATX.GI,OSEAX.GI,TA100.GI,ISEQ.GI,LUXXX.GI,PX.GI,KAX.GI,HEX.GI,ASE.GI,N225.GI,TSE2.GI,TPX.GI,JSDA.GI,STI.GI,KS11.GI,SENSEX.GI,AORD.GI,AS51.GI,NZ50.GI,JKSE.GI,KLSE.GI,SETI.GI,PSI.GI,BLOM.GI,VNINDEX.GI,SASEIDX.GI,000001.SH,399001.SZ,HSI.HI,TWII.TW"

# %%
# namelist0="IBOVESPA.GI,DJI.GI,IXIC.GI,SPX.GI,FTSE.GI,FCHI.GI,GDAXI.GI,N225.GI,KS11.GI,HSI.HI,AS51.GI,SENSEX.GI,RTS.GI,000001.SH,399001.SZ,TWII.TW"

# %%
# Divide the item code into independent sub-items 将条目代码切分成独立的子项

namelist=namelist0.split(',')

# %%
k = 0 
while(k < len(namelist)):
    print(namelist[k])
    
    ds = w.wsd(namelist[k], "open,high,low,close", "2010-01-01", "2021-03-23", "ShowBlank=-1;Currency=USD")
    if ds.Data[0][0]== -1:
        k=k+1
        print('jie shu')
        continue
    sname=namelist[k].split('.')
    sname1=sname[0]+".csv"
    file_name = os.path.join(current_dir, sname1)

    csvfile = open(file_name, 'wt',newline='')  # encoding='utf-8'

    writer=csv.writer(csvfile, delimiter=",")
    header=['Date','open','high','low','close']
    if len(ds.Data)<8:
        k=k+1
        print(k)
        continue
    csvrow1=ds.Times
    csvrow2=ds.Data[0]
    csvrow3=ds.Data[1]
    csvrow4=ds.Data[2]
    csvrow5=ds.Data[3]
    #csvrow6=ds.Data[4]
    
    #csvrow7=ds.Data[5]
    #csvrow8=ds.Data[6]
    #csvrow9=ds.Data[7]
    

    writer.writerow(header)
    writer.writerows(zip(csvrow1,csvrow2,csvrow3,csvrow4,csvrow5))


    csvfile.close()
    k=k+1
    print(k)
# Out:
# ADX.GI
# jie shu
# AMX.GI
# 2
# AS52.GI
# 3
# ATXPRIME.GI
# jie shu
# BELSTK.GI
# 5
# BSE500.GI
# jie shu
# BTK.GI
# 7
# BURCAP.GI
# jie shu
# BUX.GI
# jie shu
# BVLX.GI
# jie shu
# CASE.GI
# jie shu
# CCSI.GI
# jie shu
# CDAX.F
# jie shu
# CHTX.GI
# 14
# CN20.GI
# 15
# DFM.GI
# jie shu
# DJCH30.GI
# jie shu
# DJCOMP.GI
# 18
# DJDWCF.GI
# 19
# DJES30.GI
# jie shu
# DJTR20I.GI
# jie shu
# FBMEMAS.FI
# jie shu
# FSTAS.FI
# 23
# FSTRE.GI
# 24
# FT350.FI
# 25
# FTASE.FI
# 26
# FTDUAE.FI
# jie shu
# FTITMC.FI
# 28
# FTSEM.FI
# 29
# FTSEMIB.FI
# 30
# HDAX.F
# jie shu
# HERMES.GI
# jie shu
# HEX25.FIN
# 33
# HEXP.FIN
# 34
# IBOVESPA.GI
# jie shu
# IBOVIEE.GI
# jie shu
# IBX.GI
# jie shu
# IGPA.GI
# jie shu
# IMC30.GI
# jie shu
# IMOEX.MCX
# jie shu
# INMEX.GI
# jie shu
# INTER10.GI
# jie shu
# IPSA.GI
# jie shu
# ITLMS.GI
# 44
# JKLQ45.JK
# jie shu
# KOSPI200.GI
# 46
# KRX100.GI
# jie shu
# LUXXR.GI
# 48
# MAR.GI
# jie shu
# MCX10.MCX
# jie shu
# NBI.GI
# 51
# NGSEINDX.GI
# jie shu
# ...

# %%
os.path
# Out:
# <module 'ntpath' from 'C:\\ProgramData\\Anaconda3\\lib\\ntpath.py'>

# %%
w.wsd("AS51", "open,high,low,close,amt,swing,pct_chg,turn", "2010-01-01", "2021-03-23", "Fill=Previous")
# Out:
# .ErrorCode=0
# .Codes=[AS51]
# .Fields=[OPEN,HIGH,LOW,CLOSE,AMT,SWING,PCT_CHG,TURN]
# .Times=[20100104,20100105,20100106,20100107,20100108,20100111,20100112,20100113,20100114,20100115,...]
# .Data=[[None,None,None,None,None,None,None,None,None,None,...],[None,None,None,None,None,None,None,None,None,None,...],[None,None,None,None,None,None,None,None,None,None,...],[None,None,None,None,None,None,None,None,None,None,...],[None,None,None,None,None,None,None,None,None,None,...],[None,None,None,None,None,None,None,None,None,None,...],[None,None,None,None,None,None,None,None,None,None,...],[None,None,None,None,None,None,None,None,None,None,...]]

# %%
if a.Data[0][0] is None:
    print('sfdsf')
# Out:
# sfdsf

# %%
a.Data[0]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
